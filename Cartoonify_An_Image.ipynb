# %% [markdown]
# <a href="https://colab.research.google.com/github/Suchitra-V31/OPENCV/blob/main/Cartoonify_An_Image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Image to Cartoon....**

# %% [markdown]
# The most enjoyable for kids is watching cartoons.Every kids love to watch cartoons.Even when we grew up we still desire to watch them.But what about watching our images cartoonified.Intresting!!!

# %% [markdown]
# In this notebook we are going to see how to cartoonify an image using opencv.

# %% [markdown]
# **STEP -1 :** Let us import all the necessary libraries.

# %%
#import the necessary libraries
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
from google.colab.patches import cv2_imshow

# %% [markdown]
# **STEP-2:** Load the image

# %%
#load the image
img=cv2.imread('/content/cartoon image.png')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1366x678 at 0x7FBE86261F90>

# %% [markdown]
# **STEP-3:**  Convert the image to grayscale

# %%
#convert the image to gray
img_gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
cv2_imshow(img_gray)
# Out:
# <PIL.Image.Image image mode=L size=1366x678 at 0x7FBE95038B10>

# %% [markdown]
# **STEP-4:**  Blur the image

# %%
# smoothenning of the image
img_blur=cv2.medianBlur(img_gray,5)
cv2_imshow(img_blur)
# Out:
# <PIL.Image.Image image mode=L size=1366x678 at 0x7FBE86256250>

# %% [markdown]
# **STEP-5:**  Get the edges of the images using Adaptive threshold.

# %% [markdown]
# **adaptiveThreshold(src, dst, maxValue, adaptiveMethod, thresholdType, blockSize, C)**

# %% [markdown]
# **src**− An object of the class Mat representing the source (input) image.
#
# **dst** − An object of the class Mat representing the destination (output) image.
#
# **maxValue** − A variable of double type representing the value that is to be given if pixel value is more than the threshold value.
#
# **adaptiveMethod** − A variable of integer the type representing the adaptive method to be used. This will be either of the following two values
#
# ADAPTIVE_THRESH_MEAN_C − threshold value is the mean of neighborhood area.
#
# ADAPTIVE_THRESH_GAUSSIAN_C − threshold value is the weighted sum of neighborhood values where weights are a Gaussian window.
#
# **thresholdType** − A variable of integer type representing the type of threshold to be used.
#
# **blockSize** − A variable of the integer type representing size of the pixelneighborhood used to calculate the threshold value.
#
# **C** − A variable of double type representing the constant used in the both methods (subtracted from the mean or weighted mean).

# %%
#getting the edges  for cartoon effect
get_edge=cv2.adaptiveThreshold(img_blur,255,cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,9,9)
cv2_imshow(get_edge)
# Out:
# <PIL.Image.Image image mode=L size=1366x678 at 0x7FBE851EEA50>

# %% [markdown]
# **STEP-6:** Get the light color of the image to mask with the edges.

# %% [markdown]
# **bilateralFilter(src, dst, d, sigmaColor, sigmaSpace, borderType)**

# %% [markdown]
# **src** − A Mat object representing the source (input image) for this operation.
#
# **dst** − A Mat object representing the destination (output image) for this operation.
#
# **d** − A variable of the type integer representing the diameter of the pixel neighborhood.
#
# **sigmaColor** − A variable of the type integer representing the filter sigma in the color space.
#
# **sigmaSpace** − A variable of the type integer representing the filter sigma in the coordinate space.
#
# **borderType** − An integer object representing the type of the border used.

# %%
# to get a mask image
mask_img=cv2.bilateralFilter(img,9,300,300)
cv2_imshow(mask_img)
# Out:
# <PIL.Image.Image image mode=RGB size=1366x678 at 0x7FBE851E5F90>

# %% [markdown]
# **STEP-7:**  Merge both the images and get your image cartooned.

# %%
#merge the image
cartoon_img=cv2.bitwise_and(mask_img,mask_img,mask=get_edge)
cv2_imshow(cartoon_img)
# Out:
# <PIL.Image.Image image mode=RGB size=1366x678 at 0x7FBE8518BD50>

# %% [markdown]
# Your Image is Cartooned!!!!
